# %%
import Library.Class11 as t1

# %%
t1.equi(5000,1000,0.1,0.8)
# Out:
# At time: 1000.1
# Number of particles on left side = 2531
# Number of Particles on right side = 2469

# %%
t1.radioact(100,20,0.1,0.1)

# %%
t1.radioact2(100,20,30,0.1,0.1)
