# %%
import Library.Assign2 as t1
import matplotlib.pyplot as plt
m=32768

# %%
#Question 2: Finding volume of that positive quadrant part of a sphere of unit radius, centered at origin using throwing method
t1.sphere(0.01,0.1,0.001)
# Out:
# 0.5220900900900901

# %%
#Question 3: Generating random walks and calculating the rms distance and displacement

plt.figure(0)
t1.walk(300,0.7,0.9)
plt.figure(1)
t1.walk(600,0.5,0.32)
plt.figure(2)
t1.walk(900,0.69,0.42)
# Out:
# RMS: 0.8194
# Displacement: 14.4248
# RMS: 0.8228
# Displacement: 20.3314
# RMS: 0.7979
# Displacement: 29.1008
