# %%
import Library.Class9 as t1
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(x):
    return abs(20*np.sin(np.pi*x))

f = plt.figure()
z = np.arange(0,2,0.0001)
plt.plot(z, func(z),color='blue')
plt.show()

# %%
f1 = plt.figure()

V=t1.pardif(2,4,20,10,func,0,2,0,0.5)  #def pardif(Lx,Lt,Nx,Nt,func,x0,xL,t,a)
plt.plot(V,color='blue')

V=t1.pardif(2,4,20,10,func,0,2,10,0.1) 
plt.plot(V,color='green')

V=t1.pardif(2,4,20,10,func,0,2,50,0.2)
plt.plot(V,color='red')
 
V=t1.pardif(2,4,20,10,func,0,2,200,0.2) 
plt.plot(V,color='pink')

# V=t1.pardif(2,4,20,5000,func,0,2,500,0.2) 
# plt.plot(V)
# # Lx=2
# Nx=20
# Lt=4
# Nt=5000

# %%
f1 = plt.figure()

V=t1.pardif(2,4,20,500,func,0,2,200,0.5)  #def pardif(Lx,Lt,Nx,Nt,func,x0,xL,t,a)
plt.plot(V)
