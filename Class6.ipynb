# %%
import Library.Class6 as t1 
import Library.Class3 as t2 
import matplotlib.pyplot as plt
import numpy as np

file= open('fit2.txt')
inp= file.readlines()  #Reading data from input file into array inp

A= [[float(inp[i].split(' ')[0])] for i in range(0,18)] 
B= [[float(inp[i].split(' ')[1])] for i in range(0,18)] 

C,D=t1.Fit(A,B,3)
D=t2.chelk(C,D,3)

def my_formula(x): 
    k=0
    for i in range(len(D)):
        k+=D[i][0]*(x**i)
    return k  

f = plt.figure()
x = np.linspace(20, 100, 1000)
plt.plot(x, my_formula(x))
plt.plot(A,B)
plt.show()
# Out:
# 18.0  1072.0  73760.0
# 1072.0  73760.0  5545216.0
# 73760.0  5545216.0  440359424.0
#
# 502.1
# 20355.48
# 830093.2799999998
#
# 6.19
# 2.291
# -0.028
